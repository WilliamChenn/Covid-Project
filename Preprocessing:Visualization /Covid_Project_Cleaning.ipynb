# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
df = pd.read_csv("/Users/william/Desktop/Covid Project/Covid Data.csv")
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1  03/05/2020       97
# 1            2             1    2             1  03/06/2020       97
# 2            2             1    2             2  09/06/2020        1
# 3            2             1    1             1  12/06/2020       97
# 4            2             1    2             1  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             1  9999-99-99       97
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99       97
# 1048573      2            13    2             1  9999-99-99       97
# 1048574      2            13    2             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# 0                1   65         2         2  ...       2        2
# ...

# %%
df = df.drop('USMER', axis=1)
df = df.drop('MEDICAL_UNIT', axis = 1)
df = df.drop('CLASIFFICATION_FINAL', axis = 1)
#df = df.head(10000)
values = [97,98,99]
#df = df[df.MEDICAL_UNIT.isin(values) == False]#delete
df = df[df.SEX.isin(values) == False]
df = df[df.PATIENT_TYPE.isin(values) == False]
df = df[df.INTUBED.isin(values) == False]
df = df[df.PNEUMONIA.isin(values) == False]
df = df[df.AGE.isin(values) == False]
df = df[df.PREGNANT.isin(values) == False]
df = df[df.DIABETES.isin(values) == False]
df = df[df.COPD.isin(values) == False]
df = df[df.ASTHMA.isin(values) == False]
df = df[df.INMSUPR.isin(values) == False]
df = df[df.HIPERTENSION.isin(values) == False]
df = df[df.OTHER_DISEASE.isin(values) == False]
df = df[df.CARDIOVASCULAR.isin(values) == False]
df = df[df.OBESITY.isin(values) == False]
df = df[df.RENAL_CHRONIC.isin(values) == False]
df = df[df.TOBACCO.isin(values) == False]
#df = df[df.CLASIFFICATION_FINAL.isin(values) == False] #delete
df = df[df.ICU.isin(values) == False]
#df = df[df.USMER.isin(values) == False]#delete

for col in df.columns:
    print(col)
    print(df.loc[df[col] == (97 or 98 or 99), col].count())
    print()
# Out:
# SEX
# 0
#
# PATIENT_TYPE
# 0
#
# DATE_DIED
# 0
#
# INTUBED
# 0
#
# PNEUMONIA
# 0
#
# AGE
# 0
#
# PREGNANT
# 0
#
# DIABETES
# 0
#
# COPD
# 0
#
# ASTHMA
# 0
#
# INMSUPR
# 0
#
# HIPERTENSION
# 0
#
# OTHER_DISEASE
# 0
#
# CARDIOVASCULAR
# 0
#
# OBESITY
# 0
#
# RENAL_CHRONIC
# 0
#
# TOBACCO
# 0
#
# ICU
# 0

# %%
df.loc[df['DATE_DIED'] != '9999-99-99', 'DATE_DIED'] = 1 #replace 
df.loc[df['DATE_DIED'] == '9999-99-99', 'DATE_DIED'] = 0 #replace
lastcol = df.pop('DATE_DIED')
df.insert(17,'DATE_DIED',lastcol)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [56], in <cell line: 4>()
#       2 df.loc[df['DATE_DIED'] == '9999-99-99', 'DATE_DIED'] = 0 #replace
#       3 lastcol = df.pop('DATE_DIED')
# ----> 4 df.insert(17,'DATE_DIED',lastcol)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4445, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    4442     raise TypeError("loc must be int")
#    4444 value = self._sanitize_column(value)
# -> 4445 self._mgr.insert(loc, column, value)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py:1230, in BlockManager.insert(self, loc, item, value)
#    1220 """
#    1221 Insert item at selected position.
#    1222
#    (...)
#    1227 value : np.ndarray or ExtensionArray
#    1228 """
#    1229 # insert to the axis; this could possibly raise a TypeError
# ...

# %%
df
# Out:
#          MEDICAL_UNIT  SEX  PATIENT_TYPE  INTUBED  PNEUMONIA  AGE  PREGNANT  \
# 5                   1    1             2        2          1   40         2
# 8                   1    1             2        2          2   37         2
# 9                   1    1             2        2          2   25         2
# 16                  1    1             2        2          1   80         2
# 56                  1    1             2        1          1   58         2
# ...               ...  ...           ...      ...        ...  ...       ...
# 1048535            13    1             2        2          2   79         2
# 1048553            13    1             2        2          1   61         2
# 1048554            13    1             2        2          1   63         2
# 1048567            13    1             2        2          2   23         2
# 1048569            13    1             2        2          2   56         2
#
# ...

# %%
nan_count = df.isna().sum()
print(nan_count )
# Out:
# MEDICAL_UNIT            0
# SEX                     0
# PATIENT_TYPE            0
# INTUBED                 0
# PNEUMONIA               0
# AGE                     0
# PREGNANT                0
# DIABETES                0
# COPD                    0
# ASTHMA                  0
# INMSUPR                 0
# HIPERTENSION            0
# OTHER_DISEASE           0
# CARDIOVASCULAR          0
# OBESITY                 0
# RENAL_CHRONIC           0
# TOBACCO                 0
# DATE_DIED               0
# CLASIFFICATION_FINAL    0
# ICU                     0
# dtype: int64

# %%
unrelevant_columns = ["COPD","ASTHMA","INMSUPR",
                      "OTHER_DISEASE","CARDIOVASCULAR",
                      "OBESITY","TOBACCO", 
                      "HIPERTENSION", "SEX", "PREGNANT", 
                      "INTUBED"] #Drop low correlation columns
df.drop(columns=unrelevant_columns,inplace=True)

# %%
df
# Out:
#          MEDICAL_UNIT  PATIENT_TYPE  PNEUMONIA  AGE  DIABETES  RENAL_CHRONIC  \
# 5                   1             2          1   40         2              2
# 8                   1             2          2   37         1              2
# 9                   1             2          2   25         2              2
# 16                  1             2          1   80         2              2
# 56                  1             2          1   58         2              2
# ...               ...           ...        ...  ...       ...            ...
# 1048535            13             2          2   79         2              2
# 1048553            13             2          1   61         1              2
# 1048554            13             2          1   63         2              2
# 1048567            13             2          2   23         1              2
# 1048569            13             2          2   56         1              2
#
#         DATE_DIED  CLASIFFICATION_FINAL  ICU
# ...

# %%
ax = sns.countplot(df.DATE_DIED)
plt.bar_label(ax.containers[0])
plt.title("Count of Deaths",color="black");
# Out:
# /Users/william/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Loudness feature is from -60db to 0 so we will normalise this column between 0 and 1
# Tempo feature is in BPM so we will scale between 0 and 1 too

from sklearn import preprocessing

#scale age
values = df.values
list = df.columns.tolist()
min_max_scaler = preprocessing.MinMaxScaler()
df_scaled = min_max_scaler.fit_transform(values)
df = pd.DataFrame(df_scaled)
df.columns = list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 7>()
#       4 from sklearn import preprocessing
#       6 #scale age
# ----> 7 values = df.values
#       8 list = df.columns.tolist()
#       9 min_max_scaler = preprocessing.MinMaxScaler()
#
# NameError: name 'df' is not defined

# %%
df.hist(bins=50,figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'MEDICAL_UNIT'}>,
#         <AxesSubplot:title={'center':'PATIENT_TYPE'}>,
#         <AxesSubplot:title={'center':'PNEUMONIA'}>],
#        [<AxesSubplot:title={'center':'AGE'}>,
#         <AxesSubplot:title={'center':'DIABETES'}>,
#         <AxesSubplot:title={'center':'RENAL_CHRONIC'}>],
#        [<AxesSubplot:title={'center':'DATE_DIED'}>,
#         <AxesSubplot:title={'center':'CLASIFFICATION_FINAL'}>,
#         <AxesSubplot:title={'center':'ICU'}>]], dtype=object)

# %%
# to describe numerical features we can use describe()
df.describe()
# Out:
#        MEDICAL_UNIT  PATIENT_TYPE     PNEUMONIA           AGE      DIABETES  \
# count  76749.000000       76749.0  76749.000000  76749.000000  76749.000000
# mean       0.522895           0.0      0.432188      0.459026      0.683344
# std        0.307002           0.0      0.495383      0.175967      0.465175
# min        0.000000           0.0      0.000000      0.000000      0.000000
# 25%        0.250000           0.0      0.000000      0.347826      0.000000
# 50%        0.333333           0.0      0.000000      0.478261      1.000000
# 75%        0.916667           0.0      1.000000      0.582609      1.000000
# max        1.000000           0.0      1.000000      1.000000      1.000000
#
#        RENAL_CHRONIC     DATE_DIED  CLASIFFICATION_FINAL           ICU
# count   76749.000000  76749.000000          76749.000000  76749.000000
# mean        0.937328      0.310219              0.612570      0.922123
# std         0.242373      0.462586              0.319892      0.267980
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
# ----> 1 ax = sns.countplot(df.DATE_DIED)
#       2 plt.bar_label(ax.containers[0])
#       3 plt.title("Count of ICU Missing Values",color="black")
#
# NameError: name 'sns' is not defined
